# %%
# %matplotlib inline

# %%
if True: 
    import matplotlib.pylab as plt
    import numpy as np
    
    def myfloat(b):
        try: 
            b = float(b)
        except ValueError:
            b = [b for b in b.split('-') if b]
            b = float(b[0])*10**(-float(b[1]))
        return b
    
    t = []
    itp = []  #  print step
    it = []   #  time step
    f =  open("output/time.out", 'r')
    f.next()
    for line in f:
        a = (line.strip().split(" "))
        a = [b for b in a if b]
        t.append(float(a[0]))
        itp.append(int(a[1]))
        it.append(int(a[2]))

# %%
f =  open("output/meta.out", 'r')
slope = float(f.next().strip().split(" ")[-1])
h0 = 0.
for line in f:
    a = line.strip().split(" ")
    a = [b for b in a if b]
    try:
        int(a[0])
        h0 += float(a[-1])
    except ValueError:
        dt = float(a[-1])
tmax = t[-1]
h0 = h0/3.
fmtstr = "h0={0:.2f}; dt={1:.1f}; slope={2:.2f}".format(h0, dt, slope)
prntstr = "_".join(fmtstr.strip().split("; "))
print fmtstr, "\t", prntstr
# Out:
# h0=0.15; dt=0.2; slope=0.20 	h0=0.15_dt=0.2_slope=0.20

# %%
ntstep = len(itp)
tmax = t[-1]
dt = (t[-1] - t[-2])/(it[-1] - it[-2])
hnorm = 0.4
case = "basin"

# %%
def get_dvol(fname):
    t = []; 
    dvol = [];
    infl = []; 
    flux = []
    f = open(fname, 'r'); 
    for line in f:
        a = (line.strip().split(" "))
        a = [myfloat(b) for b in a if b]
        t.append(a[0])
        dvol.append(a[1])
        flux.append(a[2])
        infl.append(a[3])
    t = np.array(t)
    dvol = np.array(dvol)
    flux = np.array(flux)
    infl = np.array(infl)
    total = dvol  - flux - infl
    return t, dvol, flux, infl, total

# %%
# t_check, dvol_check, flux_check, infl_check, total_check  = get_dvol('dvol.out')
# print sum(dvol_check-dvol), sum(flux_check-flux), sum(infl_check-infl)

# %%
t, dvol, flux, infl, total  = get_dvol('output/dvol.out')
ti = 0; tf =len(t)-1;  nprt = 10

f = plt.figure(figsize= (9,5.5))
plt.subplot(211)
plt.plot(t[ti:tf:nprt], dvol[ti:tf:nprt] - flux[ti:tf:nprt] - infl[ti:tf:nprt], '.', ms = 2)
# plt.plot(t[ti:tf:nprt**2], dvol[ti:tf:nprt**2] - flux[ti:tf:nprt**2] - infl[ti:tf:nprt**2], '.', ms = 6)
plt.title('mass balance (dV - fluxes - infiltration)', fontsize = 10)
plt.ylabel('volume (m$^3$)'); plt.xlim([t[ti], t[tf]])
plt.subplot(212)
plt.plot(t[ti:tf:nprt],np.cumsum(total)[ti:tf:nprt], '.', ms = 2)
plt.title('cumulative mass balance', fontsize = 10)
plt.xlabel('time (s)'); plt.ylabel('volume (m$^3$)');
plt.xlim([t[ti], t[tf]])
plt.suptitle('{1}: {0}'.format(fmtstr, case  ))
f.savefig('plots/dV_{0}.pdf'.format(prntstr))

# %%
 if True:
    dVmax = np.zeros(len(total))
    for i in range(len(total)-1):
        if np.abs(total[i+1]) > dVmax[i]:
            dVmax[i+1] = np.abs(total[i+1])
        else:
            dVmax[i+1] = dVmax[i]
    cumTot = np.cumsum(total)
    dV = np.zeros(len(cumTot))
    for i in range(len(cumTot)-1):
        if np.abs(cumTot[i+1]) > dV[i]:
            dV[i+1] = np.abs(cumTot[i+1])
        else:
            dV[i+1] = dV[i]

# %%
fig = plt.figure(figsize= (9,5.5))
plt.subplot(211)
plt.plot(t, dVmax, label = 'increment')
plt.plot(t, dV, label= 'cumulative')
plt.legend(loc = 'best')
plt.title('Maximum volume error \n {0}'.format(fmtstr))
fig.savefig('plots/dVmax_{0}.pdf'.format(prntstr))

# %%
def allfluxes():
    t = []; 
    flux1 = [];
    flux2 = [];
    flux3 = [];
    flux4 = [];    
    f = open("output/allfluxes.out", 'r'); 
    for line in f:
        a = (line.strip().split(" "))
        a = [myfloat(b) for b in a if b]
        flux1.append(a[0])
        flux2.append(a[1])
        flux3.append(a[2])
        flux4.append(a[3])
    flux1 = np.array(flux1)
    flux2 = np.array(flux2)
    flux3 = np.array(flux3)
    flux4 = np.array(flux4)    
    return flux1, flux2, flux3, flux4

# %%
flux1, flux2, flux3, flux4 = allfluxes()

# %%
## all fluxes
t, dvol, flux, infl, total  = get_dvol('output/dvol.out')

ti =0; tf = len(t)+1;  nprt = 20
f = plt.figure(figsize= (8,6))
plt.subplot(211)
plt.plot(t[ti:tf:nprt], dvol[ti:tf:nprt], '.', ms = 2, label = 'dV')
plt.plot(t[ti:tf:nprt], flux[ti:tf:nprt], '.', ms = 2,label = 'fluxes')
plt.plot(t[ti:tf:nprt], infl[ti:tf:nprt], '.', ms = 2, label = 'infl')
plt.title('Time step flux components ', fontsize = 11)
plt.ylabel('volume (m$^3$)')
plt.legend(loc = 'best', fontsize= 11)

plt.subplot(212)
plt.plot(t[ti:tf:nprt], np.cumsum(dvol)[ti:tf:nprt], '.', ms = 2, label = 'volume')
plt.plot(t[ti:tf:nprt],  np.cumsum(flux)[ti:tf:nprt], '.', ms = 2, label = 'fluxes')
plt.plot(t[ti:tf:nprt],  np.cumsum(infl)[ti:tf:nprt], '.', ms = 2, label = 'infiltration')
plt.legend(loc = 'best', fontsize= 11)
plt.title('cumulative flux components', fontsize = 11)
plt.ylabel('volume (m$^3$)'); plt.xlabel('time (s)')

# %%
f = []
ts = []
fdum = np.zeros([95 ]) 

for line in open("output/fluxes.out", 'r'):
    a = (line.strip().split(" "))
    try:
        a = [str(b) for b in a if b]        
        j = int(a[0])
        k = int(a[1])
        fdum[j] = a[2]   
    except ValueError:
        dumt = int(a[0])
        ts.append(float(a[1]))
        f.append(fdum.copy())
        fdum = np.zeros([95 ]) 
f = np.array(f)
ts = np.array(ts)
nfstep = len(f)

# %%
#  check influx again?
fig = plt.figure()
plt.plot(ts,f.sum(1), '.', ms = 3)
plt.title('Input flux; {0}'.format( fmtstr))
plt.xlabel('time'); plt.ylabel('m')

fig.savefig('plots/flux3_{0}.pdf'.format(prntstr))

# %%
nrow = 63
ncol = 94
area =  np.zeros([ncol+2, nrow+2])

for line in open("output/area.out", 'r'):
    a = (line.strip().split(" "))
    a = [float(b) for b in a if b]
    j = int(a[0])
    k = int(a[1])
    area[j,k] = a[2]

# %%
np.sum(area)*.05*.25
# Out:
# 296.10000000000002

# %%
print np.cumsum(infl)[-1]
print np.cumsum(dvol)[-1]
print np.cumsum(flux)[-1]
# Out:
# 658.0
# 251.284822657
# -406.715177351

# %%
xk = 3.9217e-4
ainflt = 0.5
binlft =  2.65e-7

# %%
xk**ainflt
# Out:
# 0.019803282556182446

# %%
t = np.arange(100, 2000, .2)

# %%
tnew = t[1:]
told = t[:-1]

# %%
plt.plot((xk*tnew**ainflt - xk*told**ainflt)/.2)
plt.plot(binlft*(tnew- told)/.2 )
plt.plot(.05/3600*np.ones_like(tnew))

# %%
prate = []
rinflt = []
winflt = []
binflt = []
for line in open("output/rain.out", 'r'):
    a = (line.strip().split(" "))
    a = [myfloat(b) for b in a if b]
    prate.append( a[0])
    rinflt.append( a[1])
    winflt.append( a[2])
plt.plot(prate,label =  'prate')
plt.plot(rinflt, label = 'binflt')
plt.plot(winflt, label = 'winflt')
plt.legend()

# %%
t0 = []
tnew = []
told = []
infl = []
for line in open("output/rain.out", 'r'):
    a = (line.strip().split(" "))
    a = [myfloat(b) for b in a if b]
    t0.append( a[0])
    told.append( a[1])
    tnew.append( a[2])
    infl.append(a[3])

tnew = np.asarray(tnew)
told = np.asarray(told)
infl = np.asarray(infl)

# %%
# plt.plot(t0,label =  't0')
plt.plot(tnew ,'.', label = 'tnew')
plt.plot(told, '.', label = 'told')
plt.legend(loc = 'best')
